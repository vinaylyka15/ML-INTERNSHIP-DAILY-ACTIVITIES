# %% [markdown]
# # DATA PIPE LINE

# %%
# a data pipeline is a step by step process that take raw data converts it into model ready data
# basic flow raw data--->cleanning-->processing--->model
# needing data pipeline for 
# real world /raw data is not clear
#  * missing values  *duplicate * different formats *noise and outliers
# a data pipeline ,organizes data properly ,automates steps reduces human ,error makes ml model reliable

# %%
# pipeline in sklearn
# a pipeline in sklearn is a sequence of data preprocessing steps and a machine learning model combine together to automate training and predictions

# %% [markdown]
# # Data Pipeline Flow

# %%
# 1)data collection:collecting data from differnt source: csv/excel ,apis 2)data preparation:  3)ml model trainning  4) ml model evaluation  5) ml model deployment
#2)data preparation: fixing errors and problems in data,handling missing values ,removing duplicates, fixing incorrect values, remove outliers
# 3) data preprocessing : converting data into a machine understanding format
# common techniques scaling encodig train test split
# 4) feature engineering : craeting new and better features from existing data
# binning feature creation feature selection feature transformation
